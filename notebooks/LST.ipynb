# %%
import sys
import os
from pathlib import Path

# Retrocedemos un nivel desde 'notebooks' para llegar a la raíz del proyecto
root_path = Path(os.getcwd()).parent
sys.path.append(str(root_path / "src"))

# Ahora puedes importar tu config normalmente
from goes_processor import config_satpy

# Verificación de carga de archivos (basado en tu archivo config_satpy.py)
print(f"Ruta de búsqueda Satpy: {config_satpy.satpy.config.get('config_path')}")
# Out:
# --- Configuración SatPy (v.0.0.1) ---
# ✅ Carpeta de configuración detectada: /home/legion/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/src/goes_processor/satpy_configs
#   - abi.yaml: Encontrado
#   - abi.yaml: Encontrado
#   - Cache: resample_cache
#   - Log: WARNING
# ---------------------------------------
# Ruta de búsqueda Satpy: ['/home/legion/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/src/goes_processor/satpy_configs']

# %%
# 1. Importar configuraciones globales y Satpy
#import config_satpy  # Esto registra la carpeta satpy_configs
from satpy import Scene
import matplotlib.pyplot as plt
# %matplotlib inline
import glob

# %%
# 2. Buscar un archivo .nc de LST dinámicamente
# Ajustamos la búsqueda a la carpeta de datos crudos (raw)
data_raw_path = root_path / "data" / "raw" / "noaa-goes19"

# Buscamos archivos que contengan 'LST' y terminen en '.nc'
# El patrón recursivo '**/*.nc' ayuda si están en subcarpetas por fecha
files = glob.glob(str(data_raw_path / "**/*LST*.nc"), recursive=True)

if not files:
    raise FileNotFoundError(f"No se encontraron archivos LST en: {data_raw_path}")

# Tomamos el primero de la lista para la prueba
input_file = files[0]
print(f"Archivo encontrado: {input_file}")
# Out:
# Archivo encontrado: /home/legion/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/data/raw/noaa-goes19/ABI-L2-LSTF/2026/003/05/OR_ABI-L2-LSTF-M6_G19_s20260030500230_e20260030509538_c20260030515145.nc

# %%
# 3. Cargar la escena
scn = Scene(reader="abi_l2_nc", filenames=[input_file])

# 4. Cargar tu producto personalizado (definido en abi.yaml)
product = "lstf_kelvin_color01"
scn.load([product])

# 5. Remuestrear
# Usamos el área de Full Disk 10km que mencionaste en tus scripts previos
#resampled_scn = scn.resample("goes_west_abi_f_10km") 

# 6. Visualizar
scn.show(product)

# 7. Verificar metadatos
#print(scn[product].attrs)

# %%
from pyresample import AreaDefinition

# Definición para 3600x1800 (Resolución 0.1°)
area_id = 'global_wgs84_3600x1800'
description = 'Mapa Global WGS84'
proj_id = 'epsg4326'
projection = 'EPSG:4326'
width = 3600
height = 1800
# Extensión: [lon_min, lat_min, lon_max, lat_max]
area_extent = [-180.0, -90.0, 180.0, 90.0]

target_area = AreaDefinition(area_id, description, proj_id, projection, 
                             width, height, area_extent)
# Out:
# ---------------------------------------------------------------------------
# AreaNotFound                              Traceback (most recent call last)
# Cell In[11], line 10
#       6 scn.load([product])
#       8 # 5. Remuestrear
#       9 # Usamos el área de Full Disk 10km que mencionaste en tus scripts previos
# ---> 10 resampled_scn = scn.resample("goes_west_abi_f_10km")
#      12 # 6. Visualizar
#      13 resampled_scn.show(product)
#
# File ~/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/venv/lib/python3.12/site-packages/satpy/scene.py:1001, in Scene.resample(self, destination, datasets, generate, unload, resampler, reduce_data, **resample_kwargs)
#     999     destination = self.finest_area(datasets)
#    1000 new_scn = self.copy(datasets=datasets)
# -> 1001 self._resampled_scene(new_scn, destination, resampler=resampler,
#    1002                       reduce_data=reduce_data, **resample_kwargs)
#    1004 # regenerate anything from the wishlist that needs it (combining
#    1005 # multiple resolutions, etc.)
#    1006 if generate:
#
# File ~/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/venv/lib/python3.12/site-packages/satpy/scene.py:875, in Scene._resampled_scene(self, new_scn, destination_area, reduce_data, **resample_kwargs)
#     873 new_datasets = {}
#     874 datasets = list(new_scn._datasets.values())
# --> 875 destination_area = self._get_finalized_destination_area(destination_area, new_scn)
#     877 resamplers = {}
#     878 reductions = {}
#
# File ~/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/venv/lib/python3.12/site-packages/satpy/scene.py:911, in Scene._get_finalized_destination_area(self, destination_area, new_scn)
#     909 def _get_finalized_destination_area(self, destination_area, new_scn):
#     910     if isinstance(destination_area, str):
# --> 911         destination_area = get_area_def(destination_area)
#     912     if hasattr(destination_area, "freeze"):
#     913         try:
#
# File ~/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/venv/lib/python3.12/site-packages/satpy/area.py:43, in get_area_def(area_name)
#      41 except ImportError:
#      42     from pyresample.utils import parse_area_file
# ---> 43 return parse_area_file(get_area_file(), area_name)[0]
#
# File ~/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/venv/lib/python3.12/site-packages/pyresample/area_config.py:150, in parse_area_file(area_file_name, *regions)
#     129 """Parse area information from area file.
#     130
#     131 Parameters
#    (...)    147     If a specified area is not found
#     148 """
#     149 try:
# --> 150     return _parse_yaml_area_file(area_file_name, *regions)
#     151 except (yaml.scanner.ScannerError, yaml.parser.ParserError):
#     152     return _parse_legacy_area_file(area_file_name, *regions)
#
# File ~/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/venv/lib/python3.12/site-packages/pyresample/area_config.py:204, in _parse_yaml_area_file(area_file_name, *regions)
#     202 params = area_dict.get(area_name)
#     203 if params is None:
# --> 204     raise AreaNotFound('Area "{0}" not found in file "{1}"'.format(area_name, area_file_name))
#     205 area_def = _create_area_def_from_dict(area_name, params)
#     206 res.append(area_def)
#
# AreaNotFound: 'Area "goes_west_abi_f_10km" not found in file "[\'/home/legion/bulk/MAIE_tesis2026/f01_code/MAIE_tesis_github/venv/lib/python3.12/site-packages/satpy/etc/areas.yaml\']"'

# %%
from pyresample import load_area
import os
import satpy

# Cargar el archivo como una lista
areas_list = load_area(os.path.join(os.path.dirname(satpy.__file__), 'etc', 'areas.yaml'))

# Extraer los nombres (nemos) de los objetos en la lista
nombres_areas = [area.area_id for area in areas_list]
print([name for name in nombres_areas if 'goes' in name.lower()])
# Out:
# ['goes_east_abi_f_500m', 'goes_east_abi_f_1km', 'goes_east_abi_f_2km', 'goes_west_abi_f_500m', 'goes_west_abi_f_1km', 'goes_west_abi_f_2km', 'goes_east_abi_c_500m', 'goes_east_abi_c_1km', 'goes_east_abi_c_2km', 'goes_west_abi_p_500m', 'goes_west_abi_p_1km', 'goes_west_abi_p_2km']
